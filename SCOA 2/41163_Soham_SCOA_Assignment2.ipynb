# %%
from numpy.random import randint
from numpy.random import rand
from numpy.random import normal
from random import uniform

# %%
def objective(x):
    
    a = 1
    b = 15
    return ((a - x[0]**2)+b*((x[1]-x[0]**2)**2))

# %%
def crossover(p1, p2, r_cross):
    
    
    c1, c2 = p1.copy(), p2.copy()
    r = uniform(0, 1.1)
    while(r > 1):
        r = uniform(0, 1.1)
    if r < r_cross:
        c1[0],c1[1] = p1[0], p2[1]
        c2[0],c2[1] = p2[0], p1[1]
    return c1,c2

# %%
def mutation(c, r_mut):
    
    p = c.copy()
    r = uniform(0, 1.1)
    while(r > 1):
        r = uniform(0, 1.1)
    if r < r_mut:
        idx = randint(0,2)
        p[idx] = float(normal(5,1,1))
        return p, True
    return p, False

# %%
def tournament(pop):
    
    c1 = pop[randint(0,len(pop)-1)]
    c2 = pop[randint(0,len(pop)-1)]
    f1 = objective(c1)
    f2 = objective(c2)
    
    if f1>f2:
        fittest = c1
        weakest = c2
    else:
        fittest = c2
        weakest = c1
        
    selection_rate = 0.85
    r = uniform(0,1.1)
    while r>1:
        r = uniform(0,1.1)
    if r < selection_rate:
        return fittest
    else:
        return weakest

# %%
def genetic_algorithm(objective, bounds, n_iter, n_pop, r_cross, r_mut):
    
    
    pop = []
    
    # initialize population
    for i in range(n_pop):
        individual = []
        for i in range(2):
            num = float(normal(10,2,1))
            while num < bounds[i][0] and num > bounds[i][1]:
                num = float(normal(10,2,1))
            individual.append(num)
        pop.append(individual)
    

    Nm = 0                                     # number of mutations           
    phi = 0
    sigma = 1
    best = pop[0]
    best_eval = objective(pop[0])
    
    for gen in range(n_iter):
        scores = [objective(p) for p in pop]   # get scores of all individuals in the population
        for i in range(n_pop):
            if scores[i] < best_eval:
                best, best_eval = pop[i], scores[i]
        print("\n>Generation %d, new best f(%s) = %f" % (gen, best, best_eval))
        
        next_pop = []
        for i in range(0,n_pop,2):
            # conduct tournament to get 2 parents for crossover
            p1 = tournament(pop)             
            p2 = tournament(pop)
            
            # perform crossover
            c1,c2 = crossover(p1,p2,1.0)
            
            # mutate child 1
            old_val = objective(c1)
            c1,success = mutation(c1,r_mut)
            if success:
                Nm += 1
                if objective(c1) < old_val:
                    phi = phi + 1
            
            # mutate child 2
            old_val = objective(c2)
            c2,success = mutation(c2,r_mut)
            if success:
                Nm += 1
                if objective(c2) < old_val:
                    phi = phi + 1
            
            # add children to next generation population
            next_pop.append(c1)
            next_pop.append(c2)
        
        print('Total Number of mutations:', Nm)
        if(Nm == 0):
            phi = 0
        else:
            phi = phi / Nm
        if(phi < 0.2):
            sigma = sigma/0.998
        elif(phi > 0.2):
            sigma = sigma*0.998
        
        # Calculate new adaptive mutation rate to stop too much mutation..
        r_mut = abs(normal(loc=0.0, scale=sigma, size=None))
        while r_mut > 0.2:
            r_mut = abs(normal(loc=0.0, scale=sigma, size=None))
        print('New r_mut:',r_mut)
        Nm = 0
        phi = 0
        
        # checks if population is stale
        if next_pop == pop:
            print('Stale')
            
        pop = next_pop
    return best, best_eval

# %%
bounds = [(-20,20),(-20,20)]
# total iterations or generations
n = 100
# define the population size
n_pop = 100
# crossover rate
r_cross = 0.9
# mutation rate
r_mut = 0.06

# perform the genetic algorithm search
best, score = genetic_algorithm(objective, bounds, n, n_pop, r_cross, r_mut)
print('Done!')

print('f(%s) = %f' % (best, score))
# Out:
# >Generation 0, new best f([4.923343647016763, 9.491268630212494]) = 3239.332731
# Total Number of mutations: 5
# New r_mut: 0.013925663565411407
#
# >Generation 1, new best f([4.923343647016763, 9.491268630212494]) = 3239.332731
# Total Number of mutations: 2
# New r_mut: 0.05258877973328351
#
# >Generation 2, new best f([4.923343647016763, 9.491268630212494]) = 3239.332731
# Total Number of mutations: 7
# New r_mut: 0.13237113885570637
#
# >Generation 3, new best f([4.512478101449765, 9.802180784612357]) = 1653.429560
# Total Number of mutations: 9
# New r_mut: 0.05669064608426484
#
# >Generation 4, new best f([3.988622962660213, 10.32993347250243]) = 451.999573
# Total Number of mutations: 5
# New r_mut: 0.035693731013981406
#
# >Generation 5, new best f([3.988622962660213, 10.32993347250243]) = 451.999573
# Total Number of mutations: 4
# New r_mut: 0.024910559727950764
#
# >Generation 6, new best f([3.988622962660213, 10.32993347250243]) = 451.999573
# Total Number of mutations: 3
# New r_mut: 0.044211476804919964
#
# >Generation 7, new best f([3.988622962660213, 10.32993347250243]) = 451.999573
# Total Number of mutations: 10
# New r_mut: 0.04443529400030492
#
# >Generation 8, new best f([2.4707996055467687, 6.58873125176643]) = -1.592745
# Total Number of mutations: 4
# New r_mut: 0.1029699166274043
#
# >Generation 9, new best f([2.4707996055467687, 6.58873125176643]) = -1.592745
# Total Number of mutations: 13
# New r_mut: 0.19773432076831204
#
# >Generation 10, new best f([2.4707996055467687, 6.58873125176643]) = -1.592745
# Total Number of mutations: 24
# New r_mut: 0.09381213389556872
#
# >Generation 11, new best f([2.4707996055467687, 6.58873125176643]) = -1.592745
# Total Number of mutations: 10
# New r_mut: 0.010985085221134032
#
# >Generation 12, new best f([2.4707996055467687, 6.58873125176643]) = -1.592745
# Total Number of mutations: 1
# New r_mut: 0.19223343665662143
#
# >Generation 13, new best f([2.4707996055467687, 6.58873125176643]) = -1.592745
# Total Number of mutations: 19
# New r_mut: 0.05823181711646671
#
# >Generation 14, new best f([2.4707996055467687, 6.58873125176643]) = -1.592745
# Total Number of mutations: 4
# New r_mut: 0.1846460454977362
#
# >Generation 15, new best f([2.4707996055467687, 6.58873125176643]) = -1.592745
# Total Number of mutations: 18
# New r_mut: 0.16760444866139326
#
# >Generation 16, new best f([2.4707996055467687, 6.58873125176643]) = -1.592745
# Total Number of mutations: 9
# New r_mut: 0.12565212184730357
#
# >Generation 17, new best f([2.4707996055467687, 6.58873125176643]) = -1.592745
# Total Number of mutations: 16
# New r_mut: 0.11306368584111044
#
# >Generation 18, new best f([2.4707996055467687, 6.58873125176643]) = -1.592745
# Total Number of mutations: 9
# New r_mut: 0.13203312832851086
#
# >Generation 19, new best f([2.4707996055467687, 6.58873125176643]) = -1.592745
# Total Number of mutations: 9
# New r_mut: 0.09111419306250323
#
# >Generation 20, new best f([2.4707996055467687, 6.58873125176643]) = -1.592745
# Total Number of mutations: 11
# New r_mut: 0.10594703805628414
#
# >Generation 21, new best f([2.4707996055467687, 6.58873125176643]) = -1.592745
# Total Number of mutations: 11
# New r_mut: 0.0028797525170060198
#
# >Generation 22, new best f([2.4707996055467687, 6.58873125176643]) = -1.592745
# Total Number of mutations: 0
# New r_mut: 0.04915559611333981
#
# >Generation 23, new best f([2.4707996055467687, 6.58873125176643]) = -1.592745
# Total Number of mutations: 4
# New r_mut: 0.04284350110683978
#
# >Generation 24, new best f([2.4707996055467687, 6.58873125176643]) = -1.592745
# Total Number of mutations: 2
# New r_mut: 0.015466477918965146
#
# >Generation 25, new best f([2.4707996055467687, 6.58873125176643]) = -1.592745
# Total Number of mutations: 1
# New r_mut: 0.04045502079874696
#
# >Generation 26, new best f([2.4707996055467687, 6.58873125176643]) = -1.592745
# Total Number of mutations: 6
# New r_mut: 0.19380584456587807
#
# >Generation 27, new best f([2.4707996055467687, 6.58873125176643]) = -1.592745
# Total Number of mutations: 17
# New r_mut: 0.0052367636939797055
#
# >Generation 28, new best f([2.4707996055467687, 6.58873125176643]) = -1.592745
# Total Number of mutations: 0
# New r_mut: 0.1829209298144477
#
# >Generation 29, new best f([2.4707996055467687, 6.58873125176643]) = -1.592745
# Total Number of mutations: 22
# New r_mut: 0.09102869041291281
#
# >Generation 30, new best f([2.4707996055467687, 6.58873125176643]) = -1.592745
# Total Number of mutations: 15
# New r_mut: 0.18014437148987836
#
# >Generation 31, new best f([2.4707996055467687, 6.58873125176643]) = -1.592745
# Total Number of mutations: 15
# New r_mut: 0.1750101024346557
#
# >Generation 32, new best f([2.4707996055467687, 6.58873125176643]) = -1.592745
# Total Number of mutations: 18
# New r_mut: 0.03615504948303461
#
# >Generation 33, new best f([2.4707996055467687, 6.58873125176643]) = -1.592745
# Total Number of mutations: 1
# New r_mut: 0.09203204618631108
#
# >Generation 34, new best f([2.4707996055467687, 6.58873125176643]) = -1.592745
# Total Number of mutations: 7
# New r_mut: 0.054342993586183566
#
# >Generation 35, new best f([2.4707996055467687, 6.58873125176643]) = -1.592745
# Total Number of mutations: 7
# New r_mut: 0.10393565554622126
#
# >Generation 36, new best f([2.4707996055467687, 6.58873125176643]) = -1.592745
# Total Number of mutations: 12
# New r_mut: 0.11131826059180787
#
# >Generation 37, new best f([2.4707996055467687, 6.58873125176643]) = -1.592745
# Total Number of mutations: 10
# New r_mut: 0.184372936012476
#
# >Generation 38, new best f([2.4707996055467687, 6.58873125176643]) = -1.592745
# Total Number of mutations: 14
# New r_mut: 0.0197535074006244
#
# >Generation 39, new best f([2.4707996055467687, 6.58873125176643]) = -1.592745
# Total Number of mutations: 3
# New r_mut: 0.1438608659447225
#
# >Generation 40, new best f([2.4707996055467687, 6.58873125176643]) = -1.592745
# Total Number of mutations: 14
# New r_mut: 0.002544520805349319
#
# >Generation 41, new best f([2.4707996055467687, 6.58873125176643]) = -1.592745
# Total Number of mutations: 1
# New r_mut: 0.15740474750665567
#
# >Generation 42, new best f([2.4707996055467687, 6.58873125176643]) = -1.592745
# Total Number of mutations: 15
# New r_mut: 0.14155297942485018
#
# >Generation 43, new best f([2.4707996055467687, 6.58873125176643]) = -1.592745
# Total Number of mutations: 11
# New r_mut: 0.029266719625834024
#
# >Generation 44, new best f([2.4707996055467687, 6.58873125176643]) = -1.592745
# Total Number of mutations: 1
# New r_mut: 0.05113867151173532
#
# >Generation 45, new best f([2.4707996055467687, 6.58873125176643]) = -1.592745
# Total Number of mutations: 6
# New r_mut: 0.09054884391254937
#
# >Generation 46, new best f([2.4707996055467687, 6.58873125176643]) = -1.592745
# Total Number of mutations: 9
# New r_mut: 0.12156724766836653
#
# >Generation 47, new best f([2.4707996055467687, 6.58873125176643]) = -1.592745
# Total Number of mutations: 13
# New r_mut: 0.1563978718931605
#
# >Generation 48, new best f([2.4707996055467687, 6.58873125176643]) = -1.592745
# Total Number of mutations: 14
# New r_mut: 0.1636388758383767
#
# >Generation 49, new best f([2.4707996055467687, 6.58873125176643]) = -1.592745
# Total Number of mutations: 18
# New r_mut: 0.09882236732224642
#
# >Generation 50, new best f([2.4707996055467687, 6.58873125176643]) = -1.592745
# Total Number of mutations: 8
# New r_mut: 0.1846461060378344
#
# >Generation 51, new best f([2.4707996055467687, 6.58873125176643]) = -1.592745
# Total Number of mutations: 14
# New r_mut: 0.06422514264398631
#
# >Generation 52, new best f([2.4707996055467687, 6.58873125176643]) = -1.592745
# Total Number of mutations: 7
# New r_mut: 0.02661221379332463
#
# >Generation 53, new best f([2.4707996055467687, 6.58873125176643]) = -1.592745
# Total Number of mutations: 2
# New r_mut: 0.1922090128490666
#
# >Generation 54, new best f([2.4707996055467687, 6.58873125176643]) = -1.592745
# Total Number of mutations: 17
# New r_mut: 0.14183988729438166
#
# >Generation 55, new best f([2.4707996055467687, 6.58873125176643]) = -1.592745
# Total Number of mutations: 17
# New r_mut: 0.1866526938544331
#
# >Generation 56, new best f([2.4707996055467687, 6.58873125176643]) = -1.592745
# Total Number of mutations: 14
# New r_mut: 0.17334076242911728
#
# >Generation 57, new best f([2.4707996055467687, 6.58873125176643]) = -1.592745
# Total Number of mutations: 13
# New r_mut: 0.11901195424598139
#
# >Generation 58, new best f([2.4707996055467687, 6.58873125176643]) = -1.592745
# Total Number of mutations: 16
# New r_mut: 0.026790451769091023
#
# >Generation 59, new best f([2.4707996055467687, 6.58873125176643]) = -1.592745
# Total Number of mutations: 2
# New r_mut: 0.16484329924602842
#
# >Generation 60, new best f([2.4707996055467687, 6.58873125176643]) = -1.592745
# Total Number of mutations: 13
# New r_mut: 0.017215629555463963
#
# >Generation 61, new best f([2.4707996055467687, 6.58873125176643]) = -1.592745
# Total Number of mutations: 1
# New r_mut: 0.08883332034883876
#
# >Generation 62, new best f([2.4707996055467687, 6.58873125176643]) = -1.592745
# Total Number of mutations: 10
# New r_mut: 0.16532181810718663
#
# >Generation 63, new best f([2.4707996055467687, 6.58873125176643]) = -1.592745
# Total Number of mutations: 24
# New r_mut: 0.13512928950513317
#
# >Generation 64, new best f([2.4707996055467687, 6.58873125176643]) = -1.592745
# Total Number of mutations: 13
# New r_mut: 0.15946880899602506
#
# >Generation 65, new best f([2.4707996055467687, 6.58873125176643]) = -1.592745
# Total Number of mutations: 12
# New r_mut: 0.03274158947122984
#
# >Generation 66, new best f([2.4707996055467687, 6.58873125176643]) = -1.592745
# Total Number of mutations: 5
# New r_mut: 0.16491125866407202
#
# >Generation 67, new best f([2.4707996055467687, 6.58873125176643]) = -1.592745
# Total Number of mutations: 14
# New r_mut: 0.16280086179358172
#
# >Generation 68, new best f([2.4707996055467687, 6.58873125176643]) = -1.592745
# Total Number of mutations: 14
# New r_mut: 0.17707320398832135
#
# >Generation 69, new best f([2.4707996055467687, 6.58873125176643]) = -1.592745
# Total Number of mutations: 20
# New r_mut: 0.07350661205748883
#
# >Generation 70, new best f([2.4707996055467687, 6.58873125176643]) = -1.592745
# Total Number of mutations: 7
# New r_mut: 0.15373216515465032
#
# >Generation 71, new best f([2.4707996055467687, 6.58873125176643]) = -1.592745
# Total Number of mutations: 13
# New r_mut: 0.1554817723196634
#
# >Generation 72, new best f([2.4707996055467687, 6.58873125176643]) = -1.592745
# Total Number of mutations: 19
# New r_mut: 0.04389692041447614
#
# >Generation 73, new best f([2.4707996055467687, 6.58873125176643]) = -1.592745
# Total Number of mutations: 4
# New r_mut: 0.0635448727563978
#
# >Generation 74, new best f([2.4707996055467687, 6.58873125176643]) = -1.592745
# Total Number of mutations: 5
# New r_mut: 0.058485624125091215
#
# >Generation 75, new best f([2.4707996055467687, 6.58873125176643]) = -1.592745
# Total Number of mutations: 9
# New r_mut: 0.13839631718409168
#
# >Generation 76, new best f([2.4707996055467687, 6.58873125176643]) = -1.592745
# Total Number of mutations: 15
# New r_mut: 0.12222770419475353
#
# >Generation 77, new best f([2.4707996055467687, 6.58873125176643]) = -1.592745
# Total Number of mutations: 15
# New r_mut: 0.0667433801912287
#
# >Generation 78, new best f([2.4707996055467687, 6.58873125176643]) = -1.592745
# Total Number of mutations: 4
# New r_mut: 0.011233344117599192
#
# >Generation 79, new best f([2.4707996055467687, 6.58873125176643]) = -1.592745
# Total Number of mutations: 1
# New r_mut: 0.05047990117204733
#
# >Generation 80, new best f([2.4707996055467687, 6.58873125176643]) = -1.592745
# Total Number of mutations: 4
# New r_mut: 0.19403026330741105
#
# >Generation 81, new best f([2.4707996055467687, 6.58873125176643]) = -1.592745
# Total Number of mutations: 18
# New r_mut: 0.014055595375947557
#
# >Generation 82, new best f([2.4707996055467687, 6.58873125176643]) = -1.592745
# Total Number of mutations: 1
# New r_mut: 0.04690031038415261
#
# >Generation 83, new best f([2.4707996055467687, 6.58873125176643]) = -1.592745
# Total Number of mutations: 6
# New r_mut: 0.04889400236099315
#
# >Generation 84, new best f([2.4707996055467687, 6.58873125176643]) = -1.592745
# Total Number of mutations: 3
# New r_mut: 0.0063082990237860945
#
# >Generation 85, new best f([2.4707996055467687, 6.58873125176643]) = -1.592745
# Total Number of mutations: 0
# New r_mut: 0.11524172946147962
#
# >Generation 86, new best f([2.4707996055467687, 6.58873125176643]) = -1.592745
# Total Number of mutations: 5
# New r_mut: 0.05272175745108927
#
# >Generation 87, new best f([2.4707996055467687, 6.58873125176643]) = -1.592745
# Total Number of mutations: 3
# New r_mut: 0.09814250941874776
#
# >Generation 88, new best f([2.4707996055467687, 6.58873125176643]) = -1.592745
# Total Number of mutations: 9
# New r_mut: 0.03011710381920497
#
# >Generation 89, new best f([2.4707996055467687, 6.58873125176643]) = -1.592745
# Total Number of mutations: 5
# New r_mut: 0.08862034701976995
#
# >Generation 90, new best f([2.4707996055467687, 6.58873125176643]) = -1.592745
# Total Number of mutations: 5
# New r_mut: 0.0216831562383831
#
# >Generation 91, new best f([2.4707996055467687, 6.58873125176643]) = -1.592745
# Total Number of mutations: 2
# New r_mut: 0.01013016124811279
#
# >Generation 92, new best f([2.4707996055467687, 6.58873125176643]) = -1.592745
# Total Number of mutations: 0
# New r_mut: 0.10746314900261514
#
# >Generation 93, new best f([2.4707996055467687, 6.58873125176643]) = -1.592745
# Total Number of mutations: 13
# New r_mut: 0.1576150124144778
#
# >Generation 94, new best f([2.4707996055467687, 6.58873125176643]) = -1.592745
# Total Number of mutations: 14
# New r_mut: 0.16523798593257213
#
# >Generation 95, new best f([2.4707996055467687, 6.58873125176643]) = -1.592745
# Total Number of mutations: 25
# New r_mut: 0.009026024784873198
#
# >Generation 96, new best f([2.4707996055467687, 6.58873125176643]) = -1.592745
# Total Number of mutations: 1
# New r_mut: 0.09619308104286463
#
# >Generation 97, new best f([2.4707996055467687, 6.58873125176643]) = -1.592745
# Total Number of mutations: 15
# New r_mut: 0.08422226082913768
#
# >Generation 98, new best f([2.4707996055467687, 6.58873125176643]) = -1.592745
# Total Number of mutations: 10
# New r_mut: 0.0666062793685224
#
# >Generation 99, new best f([2.4707996055467687, 6.58873125176643]) = -1.592745
# Total Number of mutations: 5
# New r_mut: 0.11547539393241925
# Done!
# f([2.4707996055467687, 6.58873125176643]) = -1.592745
